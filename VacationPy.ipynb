# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
from pprint import pprint
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="aed10559-518d-45fb-88c3-04aca582d02b" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0            yerofey pavlovich  53.9667  121.9667     13.45
# 1        1                 sydney mines  46.2367  -60.2177     21.84
# 2        2                       bokhan  53.1530  103.7714     13.59
# 3        3  edinburgh of the seven seas -37.0676  -12.3116     14.35
# 4        4                        kroya  -7.6331  109.2461     24.13
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        99         100        2.13      RU  1724539948
# 1        72          28        4.02      CA  1724539949
# 2        72          20        2.20      RU  1724539950
# 3        90         100       17.31      SH  1724539951
# 4        88          75        1.70      ID  1724539952

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_df = city_data_df.hvplot.points("Lng",
                                    "Lat",
                                    geo = True,
                                    tiles = "OSM",
                                    color='City',
                                    alpha=0.2,
                                    size = "Humidity"
                                   )
                                    
# Display the map
map_df
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df.loc[(city_data_df["Max Temp"]>=18) & (city_data_df["Max Temp"]<=32) & (city_data_df["Humidity"]<=55) & (city_data_df["Cloudiness"]<=60) & (city_data_df["Wind Speed"]<=11)]

# Drop any rows with null values
new_df = ideal_df.dropna()

# Display sample data
new_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 8          8                  qalat  32.1058   66.9083     22.53        14
# 11        11             fort bragg  35.1390  -79.0060     27.91        53
# 24        24             stanthorpe -28.6667  151.9500     22.16        43
# 42        42               cherokee  34.2668  -84.4499     30.59        41
# 47        47                   buka  40.8108   69.1986     18.59        42
# 51        51                 laguna  38.4210 -121.4238     26.17        53
# 80        80         guerrero negro  27.9769 -114.0611     24.81        55
# 84        84            tamanrasset  22.7850    5.5228     23.95        53
# 105      105                alamosa  37.4695 -105.8700     25.99        29
# 114      114             al qusiyah  27.4402   30.8184     30.51        37
# 141      141                   brak  27.5496   14.2714     31.34        29
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = new_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                       City Country      Lat       Lng  Humidity Hotel Name
# 8                    qalat      AF  32.1058   66.9083        14
# 11              fort bragg      US  35.1390  -79.0060        53
# 24              stanthorpe      AU -28.6667  151.9500        43
# 42                cherokee      US  34.2668  -84.4499        41
# 47                    buka      UZ  40.8108   69.1986        42
# 51                  laguna      US  38.4210 -121.4238        53
# 80          guerrero negro      MX  27.9769 -114.0611        55
# 84             tamanrasset      DZ  22.7850    5.5228        53
# 105                alamosa      US  37.4695 -105.8700        29
# 114             al qusiyah      EG  27.4402   30.8184        37
# 141                   brak      LY  27.5496   14.2714        29
# 152             filadelfia      US  39.9523  -75.1638        52
# 159                 newman      US  37.3138 -121.0208        50
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "apiKey": geoapify_key,
    "format" : "json",
    "categories": "accommodation.hotel",
    "limit": 50
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params = params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# qalat - nearest hotel: No hotel found
# fort bragg - nearest hotel: Airborne Inn Lodging
# stanthorpe - nearest hotel: Ridgemill Estate
# cherokee - nearest hotel: Quality Inn & Suites Canton, Ga
# buka - nearest hotel: No hotel found
# laguna - nearest hotel: Holiday Inn Express & Suites
# guerrero negro - nearest hotel: Plaza sal paraiso
# tamanrasset - nearest hotel: فندق الأمان
# alamosa - nearest hotel: 40 Winks Inn
# al qusiyah - nearest hotel: No hotel found
# brak - nearest hotel: فندق براك السياحي
# filadelfia - nearest hotel: The Ritz-Carlton, Philadelphia
# newman - nearest hotel: No hotel found
# karratha - nearest hotel: Karratha International Hotel
# souillac - nearest hotel: Hotel SkylineInn
# aydincik - nearest hotel: Unlu Konaklama
# korla - nearest hotel: Silver Star Hotel
# kalach-na-donu - nearest hotel: Гостиница
# razdol'noye - nearest hotel: Портовое
# rio preto da eva - nearest hotel: Hotel Santo Antonio
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_df = hotel_df.hvplot.points("Lng",
                                "Lat",
                                geo = True,
                                tiles = "OSM",
                                color='City',
                                alpha=0.2,
                                size = "Humidity",
                                hover_cols = ['Hotel Name', 'Country']
                               )

# Display the map
map_df
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
